# %%
import numpy as np

# %%
data = np.load('arrays.npz')

# %%
data.keys()
# Out:
# KeysView(NpzFile 'arrays.npz' with keys: IF_frequencies, external_frequencies, frequencies, I_data, Q_data)

# %%
data['I_data']
# Out:
# array([-0.0008587 , -0.0008866 , -0.00089271, ..., -0.00097651,
#        -0.00099563, -0.00102824], shape=(11208,))
